# %%
from matplotlib import pyplot as plt

from owls_discord.db import DB

# %%
db = DB()

# %%
interactions = list(db.get_interactions())

# %%
interactions
# Out:
# [(1742928470.7104564, 'icpc'),
#  (1742928532.8285336, 'icpc'),
#  (1742928820.2675087, 'chat'),
#  (1742928857.7455602, 'chat')]

# %%
plt.eventplot([i[0] for i in interactions])
